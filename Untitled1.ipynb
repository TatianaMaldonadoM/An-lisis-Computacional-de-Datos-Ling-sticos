# %%
import pandas as pd

# %%
tense_present = pd.read_csv('tense_present.csv',sep=',')

# %%
tense_present
# Out:
#    iso-639-3                  name value description   latitude  longitude  \
# 0        agr              Aguaruna     N          no  -5.300440 -77.921790
# 1        apu               Apurin�     N          no  -8.216920 -66.771410
# 2        arh               Arhuaco     N          no  10.701840 -73.636290
# 3        kwi          Awa-Cuaiquer     N          no   1.216525 -78.340135
# 4        brg                 Baure     N          no -13.127750 -64.183810
# ..       ...                   ...   ...         ...        ...        ...
# 59       pav                  Wari   CLI      clitic -10.699480 -64.561520
# 60       mtp  Wich� Lhamt�s Nocten     N          no -21.987995 -63.597110
# 61       yaa             Yaminahua     N          no  -9.884597 -71.596433
# 62       ame              Yanesha'     N          no -10.545390 -75.314970
# 63       yuz              Yuracar�     N          no -16.747880 -65.122410
#
#           family
# 0        Chicham
# 1       Arawakan
# ...
